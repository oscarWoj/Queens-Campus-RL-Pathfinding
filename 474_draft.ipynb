# %% [markdown]
# Reference Materials:
#
# [Overpass API/Overpass QL](https://wiki.openstreetmap.org/wiki/Overpass_API/Overpass_QL): API and Query Language for accessing Open Street Maps data.
#
# [Overpass Turbo](https://overpass-turbo.eu/): Website to help build and visualize Overpass API calls.
#
# [Networkx](https://networkx.org/documentation/networkx-2.4/reference/classes/generated/networkx.Graph.neighbors.html): To manage OSM's node and way data and connections between these objects.
#
# [OSM Parser](https://github.com/Tofull/networkx-osm/blob/master/OSMParser.py): To transform OSM data from the API into a networkx graph
#
# ## TODO
#
# - Visualization
#
# - Fix reward function to get algorithm to converge

# %% [markdown]
# # Graph Implementation:

# %% [markdown]
# ## Data Import and Preprocessing

# %%
import copy
import urllib.request
import xml.sax
from math import radians, cos, sin, asin, sqrt
from pathlib import Path

# !pip install networkx
import networkx



def haversine_distance(lon1, lat1, lon2, lat2, unit_m=True):
    """
    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees)
    default unit : km
    """
    # convert decimal degrees to radians
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * asin(sqrt(a))
    r = 6371  # Radius of the Earth in kilometers. Use 3956 for miles
    if unit_m:
        r *= 1000
    return c * r


def download_osm(left=-73.4244, bottom=45.4302, right=-73.4010, top=45.4466, proxy=False, cache=False, cacheTempDir="/tmp/tmpOSM/", verbose=True):
    """ Return a filehandle to the downloaded data from osm api."""
    if cache:
        # cached tile filename
        cachedTileFilename = "osm_map_{:.8f}_{:.8f}_{:.8f}_{:.8f}.map".format(left, bottom, right, top)

        if verbose:
            print("Cached tile filename :", cachedTileFilename)

        cacheTempDir = Path(cacheTempDir)
        cacheTempDir.mkdir(parents=True, exist_ok=True)  # Create cache path if not exists

        osmFile = Path(cacheTempDir / cachedTileFilename).resolve()  # Replace the relative cache folder path to absolute path

        if osmFile.is_file():
            # download from the cache folder
            if verbose:
                print("Tile loaded from the cache folder.")

            with open(osmFile, mode='r') as f:
                content = f.read()
            return content

    if proxy:
        # configure the urllib request with the proxy
        proxy_handler = urllib.request.ProxyHandler({'https': 'https://' + proxyHost + ":" + proxyPort, 'http': 'http://' + proxyHost + ":" + proxyPort})
        opener = urllib.request.build_opener(proxy_handler)
        urllib.request.install_opener(opener)

    request = "http://api.openstreetmap.org/api/0.6/map?bbox=%f,%f,%f,%f" % (left, bottom, right, top)

    if verbose:
        print("Download the tile from osm web api ... in progress")
        print("Request :", request)

    fp = urllib.request.urlopen(request)
    content = fp.read().decode('utf-8')

    if verbose:
        print("OSM Tile downloaded")

    if cache:
        if verbose:
            print("Write osm tile in the cache")

        with open(osmFile, 'w') as f:
            f.write(content)

        if osmFile.is_file():
            if verbose:
                print("OSM tile written in the cache")

    return content


def read_osm(osm_xml_data, is_xml_string=True, only_roads=True):
    """Read graph in OSM format from file specified by name or by stream object.
    Parameters
    ----------
    filename_or_stream : filename or stream object
    Returns
    -------
    G : Graph
    Examples
    --------
    >>> G=nx.read_osm(nx.download_osm(-122.33,47.60,-122.31,47.61))
    >>> import matplotlib.pyplot as plt
    >>> plt.plot([G.node[n]['lat']for n in G], [G.node[n]['lon'] for n in G], 'o', color='k')
    >>> plt.show()
    """
    osm = OSM(osm_xml_data, is_xml_string=is_xml_string)
    G = networkx.DiGraph()

    ## Add ways
    for w in osm.ways.values():
        if only_roads and 'highway' not in w.tags:
            continue

        if ('oneway' in w.tags):
            if (w.tags['oneway'] == 'yes'):
                # ONLY ONE DIRECTION
                networkx.add_path(G, w.nds, id=w.id)
            else:
                # BOTH DIRECTION
                networkx.add_path(G, w.nds, id=w.id)
                networkx.add_path(G, w.nds[::-1], id=w.id)
        else:
            # BOTH DIRECTION
            networkx.add_path(G, w.nds, id=w.id)
            networkx.add_path(G, w.nds[::-1], id=w.id)

    # Complete the used nodes' information
    coordinates_map = {}
    for n_id in G.nodes():
        n = osm.nodes[n_id]
        G.nodes[n_id]['lat'] = n.lat
        G.nodes[n_id]['lon'] = n.lon
        G.nodes[n_id]['id'] = n.id
        coordinates_map[n_id] = (n.lon, n.lat)

    # Estimate the length of each way
    for u, v, d in G.edges(data=True):
        distance = haversine_distance(G.nodes[u]['lon'], G.nodes[u]['lat'], G.nodes[v]['lon'], G.nodes[v]['lat'], unit_m=True)  # Give a realistic distance estimation (neither EPSG nor projection nor reference system are specified)

        G.add_weighted_edges_from([(u, v, distance)], weight='havlen')

    G = networkx.relabel_nodes(G, coordinates_map)
    return G


class Node(object):
    def __init__(self, id, lon, lat):
        self.id = id
        self.lon = lon
        self.lat = lat
        self.tags = {}

    def __str__(self):
        return "Node (id : %s) lon : %s, lat : %s "%(self.id, self.lon, self.lat)


class Way(object):
    def __init__(self, id, osm):
        self.osm = osm
        self.id = id
        self.nds = []
        self.tags = {}

    def split(self, dividers):
        # slice the node-array using this nifty recursive function
        def slice_array(ar, dividers):
            for i in range(1,len(ar)-1):
                if dividers[ar[i]]>1:
                    left = ar[:i+1]
                    right = ar[i:]

                    rightsliced = slice_array(right, dividers)

                    return [left]+rightsliced
            return [ar]

        slices = slice_array(self.nds, dividers)

        # create a way object for each node-array slice
        ret = []
        i = 0
        for slice in slices:
            littleway = copy.copy(self)
            littleway.id += "-%d" % i
            littleway.nds = slice
            ret.append(littleway)
            i += 1

        return ret


class OSM(object):
    def __init__(self, osm_xml_data, is_xml_string=True):
        """ File can be either a filename or stream/file object.
        set `is_xml_string=False` if osm_xml_data is a filename or a file stream.
        """
        nodes = {}
        ways = {}

        superself = self

        class OSMHandler(xml.sax.ContentHandler):
            @classmethod
            def setDocumentLocator(self, loc):
                pass

            @classmethod
            def startDocument(self):
                pass

            @classmethod
            def endDocument(self):
                pass

            @classmethod
            def startElement(self, name, attrs):
                if name == 'node':
                    self.currElem = Node(attrs['id'], float(attrs['lon']), float(attrs['lat']))
                elif name == 'way':
                    self.currElem = Way(attrs['id'], superself)
                elif name == 'tag':
                    self.currElem.tags[attrs['k']] = attrs['v']
                elif name == 'nd':
                    self.currElem.nds.append(attrs['ref'])

            @classmethod
            def endElement(self, name):
                if name == 'node':
                    nodes[self.currElem.id] = self.currElem
                elif name == 'way':
                    ways[self.currElem.id] = self.currElem

            @classmethod
            def characters(self, chars):
                pass

        if is_xml_string:
            xml.sax.parseString(osm_xml_data, OSMHandler)
        else:
            with open(osm_xml_data, mode='r') as f:
                xml.sax.parse(f, OSMHandler)

        self.nodes = nodes
        self.ways = ways

        # count times each node is used
        node_histogram = dict.fromkeys(self.nodes.keys(), 0)
        for way in self.ways.values():
            if len(way.nds) < 2:  # if a way has only one node, delete it out of the osm collection
                del self.ways[way.id]
            else:
                for node in way.nds:
                    node_histogram[node] += 1

        # use that histogram to split all ways, replacing the member set of ways
        new_ways = {}
        for id, way in self.ways.items():
            split_ways = way.split(node_histogram)
            for split_way in split_ways:
                new_ways[split_way.id] = split_way
        self.ways = new_ways
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (2.8.8)

# %% [markdown]
# ## Create and parse Graph from osm data

# %%
from matplotlib import pyplot as plt

d = download_osm(left=-76.5017059541, bottom=44.2224495448, right=-76.4903552918, top=44.2298231916)
G = read_osm(d,only_roads=True)

# G is undirected

# G is now directed
G = G.to_undirected() #With this
print(G.nodes)

plt.plot([G.nodes[n]['lat']for n in G], [G.nodes[n]['lon'] for n in G], 'o', color='k', alpha=0.2)
plt.show()

print(type(G))
# Out:
# Download the tile from osm web api ... in progress
# Request : http://api.openstreetmap.org/api/0.6/map?bbox=-76.501706,44.222450,-76.490355,44.229823
# OSM Tile downloaded
# [(-76.4905204, 44.2249349), (-76.4906166, 44.2249251), (-76.4908169, 44.2249044), (-76.4910503, 44.2248791), (-76.4916043, 44.2247953), (-76.4920893, 44.2247281), (-76.4925185, 44.2246686), (-76.4933756, 44.2245498), (-76.4937009, 44.2245047), (-76.4941718, 44.2244394), (-76.4945764, 44.2243834), (-76.4949564, 44.2243307), (-76.4950209, 44.2243218), (-76.4981811, 44.2226623), (-76.4981973, 44.2227323), (-76.4982021, 44.2227555), (-76.4982693, 44.2232467), (-76.4983231, 44.2237133), (-76.4983266, 44.2237433), (-76.4983337, 44.2238048), (-76.4828884, 44.226855), (-76.4829824, 44.2268996), (-76.4830129, 44.226914), (-76.4831565, 44.2269821), (-76.4835019, 44.2271458), (-76.4838035, 44.2272888), (-76.4838653, 44.2273181), (-76.4839521, 44.2273593), (-76.4840286, 44.2273956), (-76.4840597, 44.2274103), (-76.4851312, 44.2279182), (-76.485196, 44.227949), (-76.4852796, 44.2279886), (-76.4863747, 44.2285077), (-76.4864231, 44.2285307), (-76.4864915, 44.2285558), (-76.4865676, 44.2285835), (-76.4866135, 44.2285972), (-76.4871006, 44.2286959), (-76.4880388, 44.228896), (-76.4881183, 44.2289116), (-76.4881916, 44.2289262), (-76.4886121, 44.2290133), (-76.4894712, 44.2292026), (-76.4899022, 44.2292939), (-76.4899803, 44.2293064), (-76.4901978, 44.2293557), (-76.4907761, 44.2294789), (-76.4908658, 44.2295031), (-76.4909083, 44.2295191), (-76.4909811, 44.2295464), (-76.4985763, 44.2249399), (-76.4982972, 44.2250068), (-76.4980763, 44.2250433), (-76.4978081, 44.2250533), (-76.4974769, 44.225044), (-76.497325, 44.2250269), (-76.4971848, 44.2250014), (-76.4970673, 44.2249744), (-76.4969646, 44.2249556), (-76.4968201, 44.224943), (-76.4966407, 44.2249431), (-76.4963321, 44.2249666), (-76.4961912, 44.2249823), (-76.4959479, 44.2250233), (-76.4957391, 44.2250612), (-76.4956884, 44.2250672), (-76.4955918, 44.2250754), (-76.5015038, 44.2286198), (-76.5014408, 44.2286223), (-76.5013808, 44.2286254), (-76.5010456, 44.2286363), (-76.5000076, 44.2286702), (-76.4998851, 44.2286743), (-76.4918741, 44.2276719), (-76.4918662, 44.2275877), (-76.491841, 44.2273197), (-76.491738, 44.2262218), (-76.4916949, 44.225762), (-76.491612, 44.2248777), (-76.49161, 44.2248575), (-76.4934104, 44.2277693), (-76.4934131, 44.2276864), (-76.4934037, 44.2271164), (-76.4934016, 44.2269896), (-76.493398, 44.2267725), (-76.493394, 44.2265331), (-76.4933926, 44.2264443), (-76.4885384, 44.2277948), (-76.4886024, 44.2277079), (-76.488786, 44.2276208), (-76.4891333, 44.2274723), (-76.4894083, 44.2273707), (-76.4896736, 44.2273106), (-76.4898404, 44.227297), (-76.4900984, 44.2273088), (-76.4903494, 44.2273276), (-76.490602, 44.2273633), (-76.4906226, 44.2273685), (-76.4907613, 44.2273712), (-76.4950197, 44.2242586), (-76.4950196, 44.2242416), (-76.495016, 44.223783), (-76.4950136, 44.2234828), (-76.4950132, 44.2234244), (-76.4950128, 44.22338), (-76.4950104, 44.2230727), (-76.4950102, 44.2230472), (-76.4950097, 44.2229796), (-76.5011846, 44.2246478), (-76.5011277, 44.2246516), (-76.5010684, 44.2246556), (-76.5005909, 44.2247094), (-76.5004665, 44.2247234), (-76.500337, 44.224738), (-76.4996692, 44.2248132), (-76.4995823, 44.2247957), (-76.4995295, 44.2247672), (-76.4994711, 44.224723), (-76.4944441, 44.2297833), (-76.4944386, 44.2298306), (-76.4943683, 44.2305388), (-76.4943657, 44.2305667), (-76.4943616, 44.2306114), (-76.4943578, 44.2306589), (-76.4943555, 44.2306879), (-76.4942878, 44.2314111), (-76.4942846, 44.2314379), (-76.4942742, 44.2314952), (-76.4929831, 44.2277422), (-76.4929757, 44.2278367), (-76.4930016, 44.2283166), (-76.4930434, 44.2288655), (-76.4930475, 44.2289331), (-76.4930448, 44.2290201), (-76.4930026, 44.2296496), (-76.493004, 44.2296934), (-76.493005, 44.2297605), (-76.4930003, 44.23048), (-76.4929987, 44.2305337), (-76.492997, 44.2305993), (-76.4929796, 44.2312336), (-76.4929655, 44.2312935), (-76.5013746, 44.2270112), (-76.5013831, 44.2270829), (-76.5013853, 44.2271107), (-76.5014251, 44.2276127), (-76.5015794, 44.2295864), (-76.5015831, 44.2296344), (-76.50 ...
# <class 'networkx.classes.graph.Graph'>

# %% [markdown]
# Nodes are (lat,lon) tuples of coordinates

# %%
NV = G.nodes()
i = 0
for n in NV:
  i+=1
  if i < 100:
    print(n)
    print(type(n))
    #print()

#print(np.random.choice(NV[0]))
# Out:
# (-76.4905204, 44.2249349)
# <class 'tuple'>
# (-76.4906166, 44.2249251)
# <class 'tuple'>
# (-76.4908169, 44.2249044)
# <class 'tuple'>
# (-76.4910503, 44.2248791)
# <class 'tuple'>
# (-76.4916043, 44.2247953)
# <class 'tuple'>
# (-76.4920893, 44.2247281)
# <class 'tuple'>
# (-76.4925185, 44.2246686)
# <class 'tuple'>
# (-76.4933756, 44.2245498)
# <class 'tuple'>
# (-76.4937009, 44.2245047)
# <class 'tuple'>
# (-76.4941718, 44.2244394)
# <class 'tuple'>
# (-76.4945764, 44.2243834)
# <class 'tuple'>
# (-76.4949564, 44.2243307)
# <class 'tuple'>
# (-76.4950209, 44.2243218)
# <class 'tuple'>
# (-76.4981811, 44.2226623)
# <class 'tuple'>
# (-76.4981973, 44.2227323)
# <class 'tuple'>
# (-76.4982021, 44.2227555)
# <class 'tuple'>
# (-76.4982693, 44.2232467)
# <class 'tuple'>
# (-76.4983231, 44.2237133)
# <class 'tuple'>
# (-76.4983266, 44.2237433)
# <class 'tuple'>
# (-76.4983337, 44.2238048)
# <class 'tuple'>
# (-76.4828884, 44.226855)
# <class 'tuple'>
# (-76.4829824, 44.2268996)
# <class 'tuple'>
# (-76.4830129, 44.226914)
# <class 'tuple'>
# (-76.4831565, 44.2269821)
# <class 'tuple'>
# (-76.4835019, 44.2271458)
# <class 'tuple'>
# (-76.4838035, 44.2272888)
# <class 'tuple'>
# (-76.4838653, 44.2273181)
# <class 'tuple'>
# (-76.4839521, 44.2273593)
# <class 'tuple'>
# (-76.4840286, 44.2273956)
# <class 'tuple'>
# (-76.4840597, 44.2274103)
# <class 'tuple'>
# (-76.4851312, 44.2279182)
# <class 'tuple'>
# (-76.485196, 44.227949)
# <class 'tuple'>
# (-76.4852796, 44.2279886)
# <class 'tuple'>
# (-76.4863747, 44.2285077)
# <class 'tuple'>
# (-76.4864231, 44.2285307)
# <class 'tuple'>
# (-76.4864915, 44.2285558)
# <class 'tuple'>
# (-76.4865676, 44.2285835)
# <class 'tuple'>
# (-76.4866135, 44.2285972)
# <class 'tuple'>
# (-76.4871006, 44.2286959)
# <class 'tuple'>
# (-76.4880388, 44.228896)
# <class 'tuple'>
# (-76.4881183, 44.2289116)
# <class 'tuple'>
# (-76.4881916, 44.2289262)
# <class 'tuple'>
# (-76.4886121, 44.2290133)
# <class 'tuple'>
# (-76.4894712, 44.2292026)
# <class 'tuple'>
# (-76.4899022, 44.2292939)
# <class 'tuple'>
# (-76.4899803, 44.2293064)
# <class 'tuple'>
# (-76.4901978, 44.2293557)
# <class 'tuple'>
# (-76.4907761, 44.2294789)
# <class 'tuple'>
# (-76.4908658, 44.2295031)
# <class 'tuple'>
# (-76.4909083, 44.2295191)
# <class 'tuple'>
# (-76.4909811, 44.2295464)
# <class 'tuple'>
# (-76.4985763, 44.2249399)
# <class 'tuple'>
# (-76.4982972, 44.2250068)
# <class 'tuple'>
# (-76.4980763, 44.2250433)
# <class 'tuple'>
# (-76.4978081, 44.2250533)
# <class 'tuple'>
# (-76.4974769, 44.225044)
# <class 'tuple'>
# (-76.497325, 44.2250269)
# <class 'tuple'>
# (-76.4971848, 44.2250014)
# <class 'tuple'>
# (-76.4970673, 44.2249744)
# <class 'tuple'>
# (-76.4969646, 44.2249556)
# <class 'tuple'>
# (-76.4968201, 44.224943)
# <class 'tuple'>
# (-76.4966407, 44.2249431)
# <class 'tuple'>
# (-76.4963321, 44.2249666)
# <class 'tuple'>
# (-76.4961912, 44.2249823)
# <class 'tuple'>
# (-76.4959479, 44.2250233)
# <class 'tuple'>
# (-76.4957391, 44.2250612)
# <class 'tuple'>
# (-76.4956884, 44.2250672)
# <class 'tuple'>
# (-76.4955918, 44.2250754)
# <class 'tuple'>
# (-76.5015038, 44.2286198)
# <class 'tuple'>
# (-76.5014408, 44.2286223)
# <class 'tuple'>
# (-76.5013808, 44.2286254)
# <class 'tuple'>
# (-76.5010456, 44.2286363)
# <class 'tuple'>
# (-76.5000076, 44.2286702)
# <class 'tuple'>
# (-76.4998851, 44.2286743)
# <class 'tuple'>
# (-76.4918741, 44.2276719)
# <class 'tuple'>
# (-76.4918662, 44.2275877)
# <class 'tuple'>
# (-76.491841, 44.2273197)
# <class 'tuple'>
# (-76.491738, 44.2262218)
# <class 'tuple'>
# (-76.4916949, 44.225762)
# <class 'tuple'>
# (-76.491612, 44.2248777)
# <class 'tuple'>
# (-76.49161, 44.2248575)
# <class 'tuple'>
# (-76.4934104, 44.2277693)
# <class 'tuple'>
# (-76.4934131, 44.2276864)
# <class 'tuple'>
# (-76.4934037, 44.2271164)
# <class 'tuple'>
# (-76.4934016, 44.2269896)
# <class 'tuple'>
# (-76.493398, 44.2267725)
# <class 'tuple'>
# (-76.493394, 44.2265331)
# <class 'tuple'>
# (-76.4933926, 44.2264443)
# <class 'tuple'>
# (-76.4885384, 44.2277948)
# <class 'tuple'>
# (-76.4886024, 44.2277079)
# <class 'tuple'>
# (-76.488786, 44.2276208)
# <class 'tuple'>
# (-76.4891333, 44.2274723)
# <class 'tuple'>
# (-76.4894083, 44.2273707)
# <class 'tuple'>
# (-76.4896736, 44.2273106)
# <class 'tuple'>
# (-76.4898404, 44.227297)
# <class 'tuple'>
# (-76.4900984, 44.2273088)
# <class 'tuple'>
# (-76.4903494, 44.2273276)
# <class 'tuple'>
# (-76.490602, 44.2273633)
# <class 'tuple'>
# (-76.4906226, 44.2273685)
# <class 'tuple'>

# %%
for n in NV:
  i+=1
  if i < 200:
    print(G.neighbors(n))

# %% [markdown]
# ### Enviroment

# %%
class CWorld:
  def __init__(self, data: networkx.classes.digraph.DiGraph,start: tuple,terminal: tuple):
    self._terminal = terminal
    self._start = start
    self.data = data 

  def get_adjacent(self, node: tuple):
    # Get adjacent nodes from original node
    #return: nodes (should be tuple of coordinates)
    return self.data.neighbors(node)

  def get_reward(self, nodeStart: tuple, nodeEnd: tuple):
    #Get reward (distance, in meters between two nodes) - Haversine formula
    #return (absolute?) number
      if nodeStart == self._terminal: #Should this be nodeEnd? someone double check the logic
        return 5
      # return - self.data.get_edge_data(nodeStart,nodeEnd)["havlen"] #reward is negative distance
      return - round(haversine_distance(nodeStart[0], nodeStart[1], nodeEnd[0], nodeEnd[1]),3)

# %% [markdown]
# ## Q-Learning

# %%
import numpy as np

class Q_learning:

  def __init__(self, world: CWorld, alpha, gamma, e, max_eps=500, max_steps=500): 
    self.q = {}
    self.alpha = alpha #(0,1)
    self.gamma = gamma 
    self.e = e # e > 0
    self.max_eps= max_eps
    self.world = world
    self.max_steps = max_steps
    self.episodes_array_stats = np.zeros(max_eps,)
    self.steps_array_stats = np.zeros(max_eps,)

    #Q-Table set up
    #States are nodes,
    #Actions are edges between these nodes
    for node in world.data.nodes():
        self.q[node] = {}
        
        if node != self.world._terminal:
        
          for adjNode in self.world.get_adjacent(node): 
            self.q[node][adjNode] = 10

        else:
          #Terminal
          for adjNode in self.world.get_adjacent(node):
              self.q[node][adjNode] = 0

  def get_next_state(self,node: tuple,epsilon=True,drop_state=None):
      eps = self.e
      if not epsilon:
        eps = 0

      #print(node1)
      #node = (node1[0],node1[1])
      #print(node)
      mx_nxt_reward = float('-inf')
      action = None

      rc = np.random.choice(['exploit','explore'], p=[1-eps, eps])

      if rc == 'exploit':
          #parse
          for s_prime in self.q[node]:
            
            if drop_state is not None:
                if s_prime == drop_state and len(self.q[node]) > 1:
                    continue
            
            nxt_reward = self.q[node][s_prime]
  
            if nxt_reward >= mx_nxt_reward:
                action = s_prime
                mx_nxt_reward = nxt_reward

      elif rc == "explore":
          action_idx = np.random.choice(len(list(self.q[node])))
          action = list(self.q[node])[action_idx]

      return action
  
  def train(self):
    total_goal = 0 # show how many times agent has hit the goal
    cur_steps = 0
    for i in range(0, self.max_eps):
        s = self.world._start
        cur2 = 0
        skip = False
        
        
        while s != self.world._terminal and cur2 < self.max_steps:
            
            cur2+=1
            cur_steps = cur_steps+1

            #Choose a from S using policy derived from q
            a = self.get_next_state(s)

            # Take action A, observe S', R
            s_prime = a
            r = (self.world.get_reward(s,s_prime))

            qsa = self.q[s][a]
            maxa = self.get_next_state(s_prime,epsilon=False)#greedy
            self.q[s][a] = qsa + self.alpha*(r + self.gamma * (self.q[s_prime][maxa]) - qsa )
            #print(str(total_goal)+": Current location is: "+str(s))
            #print("Moving to location: "+str(s_prime)+" with weight"+str(r))
            s = s_prime

            if s == self.world._terminal:
              print("===========Reached end===================================")
              total_goal+=1
              print(total_goal)
              print("Moving to location: "+str(s_prime)+" with weight"+str(r))
              print("Steps taken:" + str(cur2))
            if cur2 >= self.max_steps:
              print("=====HIT MAX STEPS=========================================")
              skip = True

        if not skip:
          self.episodes_array_stats[i] = i
          self.steps_array_stats[i] = cur_steps



  def optimal_policy(self):#start=self._start,end=self._terminal):
    # Return list of optimal policy 
    # if s is an element of type (lat,lon)
    #return:
    #[start,s2,s3,s4......,s_n-1,terminal
    nodeList = []
    s = self.world._start
    last_s = None
    e = self.world._terminal
    nodeList.append(s)

    while s != e:
      #print(s)
      s_plus1 = self.get_next_state(s,epsilon=False,drop_state=last_s) #greedy
      nodeList.append(s_plus1)
      last_s = s
      s = s_plus1
    return nodeList

# %% [markdown]
# ![Screen Shot 2022-12-07 at 2.52.50 PM.png](data:image/png;base64,...)

# %% [markdown]
# ### Enviroment

# %%
################### To do

#Run program so it works

##### Figure out whether we should do directed graph or undirected https://networkx.org/documentation/networkx-2.4/reference/classes/index.html#which-graph-class-should-i-use
#Directed means (only one way) -- Would the agent get stuck in a one way street
#Undirected means (Edge we just went through?) is allowed back in list


##### Make it look nice and functional

### function to Print Q-table a bit more nicely than it is right now (one line)

### Build interface:

# Either let user choose what buildings they want to go from / to
# Or let the user input coordinates:
  #Iterate through every coordinate and see which one has the shortest distance to original coordinate
  # assign that coordinate 

### Build output
# Either 
  #1. I have printed a map above, and a picture of the graph
  #we could a subset of the big graph with only our optimal route and overlay it on top of the OSM maps
  ##Make sure to turn osm map's interactive flag off 
  ## will have to align it

#harder probably:
#2: use osm to map, and 
  # - create .gpx (gps routes) between the points. 
  # - Import those into geoJson or something that can be added into the original OSM map i printed

##### Bugs to look out for:
# getting stuck with directed graph: i added max number of steps to maybe guard against that
#something else but i forgot lmao

# %%
#Scrap:
# making a list of campus buildings from ways with the building tag
#tempData = api.query('[bbox:44.2224495448,-76.5017059541,44.2298231916,-76.4903552918];(way;);out;')
#buildingNames = []
#wayId = []
#for w in tempData.ways:
#  #print(w.tags.keys())#[access'])
##      buildingNames.append(w.tags["name"])
 #     wayId.append(w.id)

#print(buildingNames)
#End scrap

# %% [markdown]
# ## Interface

# %% [markdown]
# Choose starting points from user

# %%
# Please uncomment a line to Choose a starting point
#s =         #Douglas Library
#s =          # Stauffer Library
#s = ((all_campus_result.get_node(805743616,True)).lat,(all_campus_result.get_node(805743616,True)).lon)         #Nixon feild

# Please uncomment a line to Choose a starting point
#t =         #Douglas Library
#t =          # Stauffer Library
#t = all_campus_result.get_node(9224895888)         #Ontario Hall
#t# = ((all_campus_result.get_node(9130940237,True)).lat,(all_campus_result.get_node(9130940237,True)).lon) #Ellis Hall

# Alternativly input coordinates to choose a starting point and ending point
#start_latitude = 
#start_longitude =
#s = coor_resolve_to_node(start_latitude,start_longitude) 

#end_latitude = 
#end_longitude =
#t = coor_resolve_to_node(end_latitude,end_longitude)  

s = (44.2249349,-76.4905204)

t = (44.2245047,-76.4937009)

def coor_resolve_to_node(latitude,longitide) -> tuple:
  # Check to do
  pass

# %%
def Interface(start: tuple, terminal: tuple, alpha=0.2,gamma=0.5,e=0.8, max_steps=5000, max_eps=100):
  max_eps2 = max_eps
  max_steps2 = max_steps
  alpha2 = alpha
  gamma2 = gamma
  e2 = e
  world = CWorld(G,start,terminal)

  print("Bulding the Table")
  agent = Q_learning(world, alpha=alpha2, gamma=gamma2, e=e2, max_steps=max_steps2,max_eps=max_eps2)
  print(agent.q)
  
  print("Training the agent")
  agent.train()
  print("Finished training the agent")
  
  #print("Showing Best route")
  #optimal_policy = agent.optimal_policy()
  #print(optimal_policy)
  return agent

# %%
#print(s) -76.4954947, 44.2251465 -> 
#print(s[1])
# Interface(s,t)

agent1 = Interface((s[1], s[0]), (t[1],t[0]),alpha=0.5,gamma=0.5,e=0.8, max_steps=20000, max_eps=100)
# the current problem is maybe happenimnng because the inputted coordinates are wrong.
# Soltuion: choose one of the coordinates from our graph?
 44.226914): 10}, (-76.4830129, 44.226914): {(-76.4829824, 44.2268996): 10, (-76.4831565, 44.2269821): 10}, (-76.4831565, 44.2269821): {(-76.4830129, 44.226914): 10, (-76.4835019, 44.2271458): 10}, (-76.4835019, 44.2271458): {(-76.4831565, 44.2269821): 10, (-76.4838035, 44.2272888): 10}, (-76.4838035, 44.2272888): {(-76.4835019, 44.2271458): 10, (-76.4838653, 44.2273181): 10}, (-76.4838653, 44.2273181): {(-76.4838035, 44.2272888): 10, (-76.4839521, 44.2273593): 10}, (-76.4839521, 44.2273593): {(-76.4838653, 44.2273181): 10, (-76.4840286, 44.2273956): 10}, (-76.4840286, 44.2273956): {(-76.4839521, 44.2273593): 10, (-76.4840597, 44.2274103): 10}, (-76.4840597, 44.2274103): {(-76.4840286, 44.2273956): 10, (-76.4851312, 44.2279182): 10}, (-76.4851312, 44.2279182): {(-76.4840597, 44.2274103): 10, (-76.485196, 44.227949): 10}, (-76.485196, 44.227949): {(-76.4851312, 44.2279182): 10, (-76.4852796, 44.2279886): 10}, (-76.4852796, 44.2279886): {(-76.485196, 44.227949): 10, (-76.4863747, 44.2285077): 10}, (-76.4863747, 44.2285077): {(-76.4852796, 44.2279886): 10, (-76.4864231, 44.2285307): 10}, (-76.4864231, 44.2285307): {(-76.4863747, 44.2285077): 10, (-76.4864915, 44.2285558): 10}, (-76.4864915, 44.2285558): {(-76.4864231, 44.2285307): 10, (-76.4865676, 44.2285835): 10}, (-76.4865676, 44.2285835): {(-76.4864915, 44.2285558): 10, (-76.4866135, 44.2285972): 10}, (-76.4866135, 44.2285972): {(-76 ...
# Training the agent
# ===========Reached end===================================
# 1
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:2463
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 2
# Moving to location: (-76.4937009, 44.2245047) with weight-38.219
# Steps taken:11506
# ===========Reached end===================================
# 3
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:4324
# ===========Reached end===================================
# 4
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:8711
# ===========Reached end===================================
# 5
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:978
# ===========Reached end===================================
# 6
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:12937
# ===========Reached end===================================
# 7
# Moving to location: (-76.4937009, 44.2245047) with weight-38.219
# Steps taken:19915
# ===========Reached end===================================
# 8
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:1765
# ===========Reached end===================================
# 9
# Moving to location: (-76.4937009, 44.2245047) with weight-38.219
# Steps taken:13244
# ===========Reached end===================================
# 10
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:10568
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 11
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:5704
# ===========Reached end===================================
# 12
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:2735
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 13
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:7447
# ===========Reached end===================================
# 14
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:14948
# ===========Reached end===================================
# 15
# Moving to location: (-76.4937009, 44.2245047) with weight-38.219
# Steps taken:7852
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 16
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:351
# ===========Reached end===================================
# 17
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:1702
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 18
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:5821
# ===========Reached end===================================
# 19
# Moving to location: (-76.4937009, 44.2245047) with weight-38.219
# Steps taken:630
# ===========Reached end===================================
# 20
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:9956
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 21
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:18597
# ===========Reached end===================================
# 22
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:6392
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 23
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:2738
# ===========Reached end===================================
# 24
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:18595
# ===========Reached end===================================
# 25
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:14676
# ===========Reached end===================================
# 26
# Moving to location: (-76.4937009, 44.2245047) with weight-38.219
# Steps taken:4504
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 27
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:16373
# ===========Reached end===================================
# 28
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:4946
# ===========Reached end===================================
# 29
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:1762
# ===========Reached end===================================
# 30
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:13573
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 31
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:10872
# ===========Reached end===================================
# 32
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:4488
# ===========Reached end===================================
# 33
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:616
# ===========Reached end===================================
# 34
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:779
# ===========Reached end===================================
# 35
# Moving to location: (-76.4937009, 44.2245047) with weight-38.219
# Steps taken:3389
# ===========Reached end===================================
# 36
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:382
# ===========Reached end===================================
# 37
# Moving to location: (-76.4937009, 44.2245047) with weight-38.219
# Steps taken:15266
# ===========Reached end===================================
# 38
# Moving to location: (-76.4937009, 44.2245047) with weight-38.219
# Steps taken:5557
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 39
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:2274
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 40
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:16429
# ===========Reached end===================================
# 41
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:436
# ===========Reached end===================================
# 42
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:13449
# ===========Reached end===================================
# 43
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:8079
# ===========Reached end===================================
# 44
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:5431
# ===========Reached end===================================
# 45
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:19734
# ===========Reached end===================================
# 46
# Moving to location: (-76.4937009, 44.2245047) with weight-38.219
# Steps taken:5178
# ===========Reached end===================================
# 47
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:13591
# ===========Reached end===================================
# 48
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:1522
# ===========Reached end===================================
# 49
# Moving to location: (-76.4937009, 44.2245047) with weight-38.219
# Steps taken:9716
# ===========Reached end===================================
# 50
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:3705
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 51
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:1243
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 52
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:10547
# ===========Reached end===================================
# 53
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:14301
# ===========Reached end===================================
# 54
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:13021
# ===========Reached end===================================
# 55
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:11633
# ===========Reached end===================================
# 56
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:8317
# ===========Reached end===================================
# 57
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:17813
# ===========Reached end===================================
# 58
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:2831
# ===========Reached end===================================
# 59
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:13609
# ===========Reached end===================================
# 60
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:13488
# ===========Reached end===================================
# 61
# Moving to location: (-76.4937009, 44.2245047) with weight-38.219
# Steps taken:5880
# ===========Reached end===================================
# 62
# Moving to location: (-76.4937009, 44.2245047) with weight-38.219
# Steps taken:6060
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 63
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:19384
# ===========Reached end===================================
# 64
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:1302
# ===========Reached end===================================
# 65
# Moving to location: (-76.4937009, 44.2245047) with weight-38.219
# Steps taken:14624
# ===========Reached end===================================
# 66
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:14466
# ===========Reached end===================================
# 67
# Moving to location: (-76.4937009, 44.2245047) with weight-38.219
# Steps taken:18296
# ===========Reached end===================================
# 68
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:6830
# ===========Reached end===================================
# 69
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:6281
# ===========Reached end===================================
# 70
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:9281
# ===========Reached end===================================
# 71
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:242
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 72
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:439
# ===========Reached end===================================
# 73
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:9332
# ===========Reached end===================================
# 74
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:1029
# =====HIT MAX STEPS=========================================
# Finished training the agent

# %%
agent2 = Interface((s[1], s[0]), (t[1],t[0]),alpha=0.5,gamma=0.9,e=0.6, max_steps=20000, max_eps=100)
# Out:
# Bulding the Table
# {(-76.4905204, 44.2249349): {(-76.4906166, 44.2249251): 10, (-76.4904534, 44.2249392): 10, (-76.4905212, 44.2249437): 10, (-76.4905148, 44.2248758): 10}, (-76.4906166, 44.2249251): {(-76.4905204, 44.2249349): 10, (-76.4908169, 44.2249044): 10, (-76.4906304, 44.2250021): 10, (-76.4906052, 44.2248614): 10}, (-76.4908169, 44.2249044): {(-76.4906166, 44.2249251): 10, (-76.4910503, 44.2248791): 10}, (-76.4910503, 44.2248791): {(-76.4908169, 44.2249044): 10, (-76.4916043, 44.2247953): 10, (-76.4910369, 44.2248081): 10}, (-76.4916043, 44.2247953): {(-76.4910503, 44.2248791): 10, (-76.4920893, 44.2247281): 10, (-76.49161, 44.2248575): 10}, (-76.4920893, 44.2247281): {(-76.4916043, 44.2247953): 10, (-76.4925185, 44.2246686): 10, (-76.492046, 44.2246693): 10, (-76.4921255, 44.2247811): 10}, (-76.4925185, 44.2246686): {(-76.4920893, 44.2247281): 10, (-76.4933756, 44.2245498): 10}, (-76.4933756, 44.2245498): {(-76.4925185, 44.2246686): 10, (-76.4937009, 44.2245047): 10, (-76.4933635, 44.2244959): 10}, (-76.4937009, 44.2245047): {(-76.4933756, 44.2245498): 0, (-76.4941718, 44.2244394): 0, (-76.4937285, 44.2245657): 0}, (-76.4941718, 44.2244394): {(-76.4937009, 44.2245047): 10, (-76.4945764, 44.2243834): 10, (-76.4941584, 44.2243852): 10}, (-76.4945764, 44.2243834): {(-76.4941718, 44.2244394): 10, (
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 1
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:4324
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 2
# Moving to location: (-76.4937009, 44.2245047) with weight-38.219
# Steps taken:6973
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 3
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:212
# ===========Reached end===================================
# 4
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:16248
# ===========Reached end===================================
# 5
# Moving to location: (-76.4937009, 44.2245047) with weight-38.219
# Steps taken:8459
# ===========Reached end===================================
# 6
# Moving to location: (-76.4937009, 44.2245047) with weight-38.219
# Steps taken:7689
# ===========Reached end===================================
# 7
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:18055
# ===========Reached end===================================
# 8
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:3646
# ===========Reached end===================================
# 9
# Moving to location: (-76.4937009, 44.2245047) with weight-38.219
# Steps taken:1262
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 10
# Moving to location: (-76.4937009, 44.2245047) with weight-38.219
# Steps taken:3829
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 11
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:8665
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 12
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:1128
# ===========Reached end===================================
# 13
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:15961
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 14
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:2854
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 15
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:18446
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 16
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:13554
# ===========Reached end===================================
# 17
# Moving to location: (-76.4937009, 44.2245047) with weight-38.219
# Steps taken:9550
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 18
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:11532
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 19
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:2283
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 20
# Moving to location: (-76.4937009, 44.2245047) with weight-7.131
# Steps taken:11529
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 21
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:17666
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 22
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:545
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 23
# Moving to location: (-76.4937009, 44.2245047) with weight-38.219
# Steps taken:17259
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 24
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:314
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 25
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:4765
# Finished training the agent

# %%
agent3 = Interface((s[1], s[0]), (t[1],t[0]),alpha=0.5,gamma=0.6,e=0.4, max_steps=20000, max_eps=100)
# Out:
# Bulding the Table
# {(-76.4905204, 44.2249349): {(-76.4906166, 44.2249251): 10, (-76.4904534, 44.2249392): 10, (-76.4905212, 44.2249437): 10, (-76.4905148, 44.2248758): 10}, (-76.4906166, 44.2249251): {(-76.4905204, 44.2249349): 10, (-76.4908169, 44.2249044): 10, (-76.4906304, 44.2250021): 10, (-76.4906052, 44.2248614): 10}, (-76.4908169, 44.2249044): {(-76.4906166, 44.2249251): 10, (-76.4910503, 44.2248791): 10}, (-76.4910503, 44.2248791): {(-76.4908169, 44.2249044): 10, (-76.4916043, 44.2247953): 10, (-76.4910369, 44.2248081): 10}, (-76.4916043, 44.2247953): {(-76.4910503, 44.2248791): 10, (-76.4920893, 44.2247281): 10, (-76.49161, 44.2248575): 10}, (-76.4920893, 44.2247281): {(-76.4916043, 44.2247953): 10, (-76.4925185, 44.2246686): 10, (-76.492046, 44.2246693): 10, (-76.4921255, 44.2247811): 10}, (-76.4925185, 44.2246686): {(-76.4920893, 44.2247281): 10, (-76.4933756, 44.2245498): 10}, (-76.4933756, 44.2245498): {(-76.4925185, 44.2246686): 10, (-76.4937009, 44.2245047): 10, (-76.4933635, 44.2244959): 10}, (-76.4937009, 44.2245047): {(-76.4933756, 44.2245498): 0, (-76.4941718, 44.2244394): 0, (-76.4937285, 44.2245657): 0}, (-76.4941718, 44.2244394): {(-76.4937009, 44.2245047): 10, (-76.4945764, 44.2243834): 10, (-76.4941584, 44.2243852): 10}, (-76.4945764, 44.2243834): {(-76.4941718, 44.2244394): 10, (-76.4949564, 44.2243307): 10, (-76.4945616, 44.224329): 10}, (-76.4949564, 44.2243307): {(-76.4945764, 44.2243834): 10, (-76.4950209, 44.2243218): 10, (-76.4949729, 44.2243878): 10}, (-76.4950209, 44.2243218): {(-76.4949564, 44.2243307): 10, (-76.4950197, 44.2242586): 10, (-76.4951331, 44.2243062): 10}, (-76.4981811, 44.2226623): {(-76.4981973, 44.2227323): 10, (-76.4980986, 44.2226704): 10, (-76.4982518, 44.2226553): 10}, (-76.4981973, 44.2227323): {(-76.4981811, 44.2226623): 10, (-76.4982021, 44.2227555): 10, (-76.4981336, 44.2227379): 10, (
44.2269821): 10}, (-76.4831565, 44.2269821): {(-76.4830129, 44.226914): 10, (-76.4835019, 44.2271458): 10}, (-76.4835019, 44.2271458): {(-76.4831565, 44.2269821): 10, (-76.4838035, 44.2272888): 10}, (-76.4838035, 44.2272888): {(-76.4835019, 44.2271458): 10, (-76.4838653, 44.2273181): 10}, (-76.4838653, 44.2273181): {(-76.4838035, 44.2272888): 10, (-76.4839521, 44.2273593): 10}, (-76.4839521, 44.2273593): {(-76.4838653, 44.2273181): 10, (-76.4840286, 44.2273956): 10}, (-76.4840286, 44.2273956): {(-76.4839521, 44.2273593): 10, (-76.4840597, 44.2274103): 10}, (-76.4840597, 44.2274103): {(-76.4840286, 44.2273956): 10, (-76.4851312, 44.2279182): 10}, (-76.4851312, 44.2279182): {(-76.4840597, 44.2274103): 10, (-76.485196, 44.227949): 10}, (-76.485196, 44.227949): {(-76.4851312, 44.2279182): 10, (-76.4852796, 44.2279886): 10}, (-76.4852796, 44.2279886): {(-76.485196, 44.227949): 10, (-76.4863747, 44.2285077): 10}, (-76.4863747, 44.2285077): {(-76.4852796, 44.2279886): 10, (-76.4864231, 44.2285307): 10}, (-76.4864231, 44.2285307): {(-76.4863747, 44.2285077): 10, (-76.4864915, 44.2285558): 10}, (-76.4864915, 44.2285558): {(-76.4864231, 44.2285307): 10, (-76.4865676, 44.2285835): 10}, (-76.4865676, 44.2285835): {(-76.4864915, 44.2285558): 10, (-76.4866135, 44.2285972): 10}, (-76.4866135, 44.2285972): {(-76 ...
# Training the agent
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 1
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:4406
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# ===========Reached end===================================
# 2
# Moving to location: (-76.4937009, 44.2245047) with weight-26.402
# Steps taken:2928
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# =====HIT MAX STEPS=========================================
# Finished training the agent

# %%
plt.plot(agent1.steps_array_stats, agent1.episodes_array_stats,"r",label="1") # Redline
plt.plot(agent2.steps_array_stats, agent2.episodes_array_stats,"b",label="2") # Blueline
plt.plot(agent3.steps_array_stats, agent3.episodes_array_stats,"y",label="3") # yellowline
plt.plot(agent4.steps_array_stats, agent4.episodes_array_stats,"g",label="4") # greenline

plt.title("Agent Performance")
plt.ylabel("# of Episodes")
plt.xlabel("# of Time Steps")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Everything below will help you build the interface

# %% [markdown]
# Using "Forms"

# %%
#@title String fields

text = 'value' #@param {type:"string"}
dropdown = '1st option' #@param ["1st option", "2nd option", "3rd option"]
text_and_dropdown = 'value' #@param ["1st option", "2nd option", "3rd option"] {allow-input: true}

print(text)
print(dropdown)
print(text_and_dropdown)
# Out:
# value
# 1st option
# value

# %%
#@title After running this cell manually, it will auto-run if you change the selected value. { run: "auto" }

option2 = "A" #@param ["A", "B", "C"]
print('You selected', option2)
# Out:
# You selected A

# %% [markdown]
# ## Map View of route

# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd

# %%
#Define coordinates of where we want to center our map
campus_coords = [44.2265204, -76.4959298]

#Create the map
my_map = folium.Map(location = campus_coords, zoom_start = 16)

#Create markers
start_coords = [s[0],s[1]]
terminal_coords = [t[0],t[1]]
#print (start_coords)

print(start_coords)

folium.Marker(start_coords, popup = 'Start').add_to(my_map)
folium.Marker(terminal_coords, popup = 'End').add_to(my_map)

#Display the map
my_map

#Whats left to display a route
# Generate a list of way ids in our code
# (do an api call?) to get OSM data for these ways
# convert .osm to .geojson (done, using !osm) !osmtogeojson file1.osm > file2.geojson
# Out:
# [44.2249349, -76.4905204]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1abb90846a851d1d089aa906f2452c21 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1abb90846a851d1d089aa906f2452c21&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1abb90846a851d1d089aa906f2452c21 = L.map(
#                 &quot;map_1abb90846a851d1d089aa906f2452c21&quot;,
#                 {
#                     center: [44.2265204, -76.4959298],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88b6d240034ab3a57d736db0eeb83f3b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1abb90846a851d1d089aa906f2452c21);
#
#
#             var marker_c9141434585039fdd2788853637b618e = L.marker(
#                 [44.2249349, -76.4905204],
#                 {}
#             ).addTo(map_1abb90846a851d1d089aa906f2452c21);
#
#
#         var popup_afa57f0afe974589f031027a5c42c92b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_778acea3b9a92bbd55fc0c59781c6654 = $(`&lt;div id=&quot;html_778acea3b9a92bbd55fc0c59781c6654&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start&lt;/div&gt;`)[0];
#             popup_afa57f0afe974589f031027a5c42c92b.setContent(html_778acea3b9a92bbd55fc0c59781c6654);
#
#
#         marker_c9141434585039fdd2788853637b618e.bindPopup(popup_afa57f0afe974589f031027a5c42c92b)
#         ;
#
#
#
#
#             var marker_09c13f2a426e71cfb13e6b773ff16d34 = L.marker(
#                 [44.2245047, -76.4937009],
#                 {}
#             ).addTo(map_1abb90846a851d1d089aa906f2452c21);
#
#
#         var popup_ecf442512aad110bd616b5c43330e9c6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7496269a5157006a62e59457002c4684 = $(`&lt;div id=&quot;html_7496269a5157006a62e59457002c4684&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;End&lt;/div&gt;`)[0];
#             popup_ecf442512aad110bd616b5c43330e9c6.setContent(html_7496269a5157006a62e59457002c4684);
#
#
#         marker_09c13f2a426e71cfb13e6b773ff16d34.bindPopup(popup_ecf442512aad110bd616b5c43330e9c6)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#!https://www.overpass-api.de/api/interpreter?data=[out:json];node[highway=speed_camera];out%20meta;
#!https://www.overpass-api.de/api/interpreter?data=[out:json];node[highway=speed_camera](43.46669501043081,-5.708215989569187,43.588927989569186,-5.605835010430813);out%20meta; --output-document=out.xml
# !https://www.overpass-api.de/api/interpreter?data=node[highway=speed_camera](43.46669501043081,-5.708215989569187,43.588927989569186,-5.605835010430813);out&20meta;;

#!wget --post-file=query.txt http://overpass-api.de/api/interpreter --output-document=out.xml
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `43.46669501043081,-5.708215989569187,43.588927989569186,-5.605835010430813'
# /bin/bash: -c: line 0: `https://www.overpass-api.de/api/interpreter?data=node[highway=speed_camera](43.46669501043081,-5.708215989569187,43.588927989569186,-5.605835010430813);out&20meta;;'

# %%
#selectedNodeIds=""
#for nodes in 
#overpass.query(node[])
#Not finished but so close -> need to figure out how to put this stupid geojson file into the foliam map and we are set
# !cp /content/cache/api-f6f7201ed9c847b8c895891416142873af55d69f /content/api1.osm
#!osmtogeojson /content/api1.osm > /content/way.geojson
geojsonFeature = "/content/way.geojson"
#print(geojsonFeature)
#folium.GeoJson(geojsonFeature).addTo(my_map);
# Out:
# cp: cannot stat '/content/cache/api-f6f7201ed9c847b8c895891416142873af55d69f': No such file or directory
